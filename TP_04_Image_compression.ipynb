# %% [markdown]
# <a id="1"></a>
# # <p style="background-color:#682F2F;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px; padding:17px ">TP 04 : Compression des images en utilisant k-means</p>

# %%
import cv2 #BGR
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# from PIL import Image
import plotly.express as px
from PIL import Image

# %%
image_color = cv2.imread("bird_small.png") 
image_color_RBG = cv2.cvtColor(image_color, cv2.COLOR_BGR2RGB)
plt.imshow(image_color_RBG)

# %% [markdown]
# Affichage

# %%
R = image_color_RBG[:,:,0]
B = image_color_RBG[:,:,1]
G = image_color_RBG[:,:,2]

fig, axes = plt.subplots(1, 3, figsize=(13, 10))

axes[0].imshow(R, cmap="Reds")
axes[0].set_title('R')

axes[1].imshow(G, cmap="Greens")
axes[1].set_title('G')

axes[2].imshow(B, cmap="Blues")
axes[2].set_title('B')

for ax in axes:
    ax.axis('off')

plt.show()

# %%
image = Image.open("bird_small.png")
image = image.convert("RGB")

# %%
image_array = np.array(image)
reshaped_array = image_array.reshape(-1, 3)

# %% [markdown]
# - Appliquation de K-means

# %%
kmeans = KMeans(n_clusters=16, random_state=0, n_init=10)
kmeans.fit(reshaped_array)
labels = kmeans.predict(reshaped_array)

# %%
compressed_image_array = kmeans.cluster_centers_[labels]
compressed_image_array = np.clip(compressed_image_array.astype('uint8'), 0, 255)
compressed_image_array = compressed_image_array.reshape(image_array.shape)

# %%
compressed_image = Image.fromarray(compressed_image_array)
plt.imshow(compressed_image)

# %% [markdown]
# <a id="1"></a>
# ### <p style="background-color:#682F2F;font-family:newtimeroman;color:#FFF9ED;font-size:100%;text-align:center;border-radius:10px 10px; padding:13px ">Fin.</p>
